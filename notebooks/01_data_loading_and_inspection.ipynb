# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Aviral\OneDrive\Desktop\EDA project\Spatiotemporal-Analysis-of-Ride-Hailing-Demand-and-Cancellation-Patterns-in-Delhi-NCR\data\raw\ncr_rides_final_event_dataset_2024.csv")
df.head(5)
# Out:
#               datetime        Date      Time  year  month  day   weekday  \
# 0  2024-03-23 12:29:38  2024-03-23  12:29:38  2024      3   23  Saturday
# 1  2024-11-29 18:01:39  2024-11-29  18:01:39  2024     11   29    Friday
# 2  2024-08-23 08:56:10  2024-08-23  08:56:10  2024      8   23    Friday
# 3  2024-10-21 17:17:25  2024-10-21  17:17:25  2024     10   21    Monday
# 4  2024-09-16 22:08:00  2024-09-16  22:08:00  2024      9   16    Monday
#
#    hour   ride_date           Event  ... Avg CTAT Cancelled Rides by Customer  \
# 0    12  2024-03-23      Normal Day  ...      NaN                         NaN
# 1    18  2024-11-29  Wedding_Season  ...     14.0                         NaN
# 2     8  2024-08-23         Monsoon  ...     25.8                         NaN
# 3    17  2024-10-21      Normal Day  ...     28.5                         NaN
# 4    22  2024-09-16      Normal Day  ...     19.6                         NaN
#
#   Reason for cancelling by Customer Cancelled Rides by Driver  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
#
#   Driver Cancellation Reason Incomplete Rides  Incomplete Rides Reason  \
# 0                        NaN              NaN                      NaN
# 1                        NaN              1.0        Vehicle Breakdown
# 2                        NaN              NaN                      NaN
# 3                        NaN              NaN                      NaN
# 4                        NaN              NaN                      NaN
#
#    Driver Ratings  Customer Rating  Payment Method
# 0             NaN              NaN             NaN
# 1             NaN              NaN             UPI
# 2             4.9              4.9      Debit Card
# 3             4.6              5.0             UPI
# 4             4.1              4.3             UPI
#
# [5 rows x 29 columns]

# %%
rows=df.shape[0]
columns=df.shape[1]
print("Number of Columns:",columns)
print("Number of Rows:",rows)
print("Columns in DataSet:\n",df.columns)
# Out:
# Number of Columns: 29
# Number of Rows: 160609
# Columns in DataSet:
#  Index(['datetime', 'Date', 'Time', 'year', 'month', 'day', 'weekday', 'hour',
#        'ride_date', 'Event', 'Booking ID', 'Booking Status', 'Customer ID',
#        'Vehicle Type', 'Pickup Location', 'Drop Location', 'Ride Distance',
#        'Booking Value', 'Avg VTAT', 'Avg CTAT', 'Cancelled Rides by Customer',
#        'Reason for cancelling by Customer', 'Cancelled Rides by Driver',
#        'Driver Cancellation Reason', 'Incomplete Rides',
#        'Incomplete Rides Reason', 'Driver Ratings', 'Customer Rating',
#        'Payment Method'],
#       dtype='str')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 160609 entries, 0 to 160608
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   datetime                           160609 non-null  str
#  1   Date                               160609 non-null  str
#  2   Time                               160609 non-null  str
#  3   year                               160609 non-null  int64
#  4   month                              160609 non-null  int64
#  5   day                                160609 non-null  int64
#  6   weekday                            160609 non-null  str
#  7   hour                               160609 non-null  int64
#  8   ride_date                          160609 non-null  str
#  9   Event                              160609 non-null  str
#  10  Booking ID                         160609 non-null  str
#  11  Booking Status                     160609 non-null  str
#  12  Customer ID                        160609 non-null  str
#  13  Vehicle Type                       160609 non-null  str
#  14  Pickup Location                    160609 non-null  str
#  15  Drop Location                      160609 non-null  str
#  16  Ride Distance                      109329 non-null  float64
#  17  Booking Value                      109329 non-null  float64
#  18  Avg VTAT                           149402 non-null  float64
#  19  Avg CTAT                           109329 non-null  float64
#  20  Cancelled Rides by Customer        11254 non-null   float64
#  21  Reason for cancelling by Customer  11254 non-null   str
#  22  Cancelled Rides by Driver          28819 non-null   float64
#  23  Driver Cancellation Reason         28819 non-null   str
#  24  Incomplete Rides                   9663 non-null    float64
#  25  Incomplete Rides Reason            9663 non-null    str
#  26  Driver Ratings                     99666 non-null   float64
#  27  Customer Rating                    99666 non-null   float64
#  28  Payment Method                     109329 non-null  str
# dtypes: float64(9), int64(4), str(16)
# memory usage: 35.5 MB
# None

# %%
print(df.isna().sum())
# Out:
# datetime                                  0
# Date                                      0
# Time                                      0
# year                                      0
# month                                     0
# day                                       0
# weekday                                   0
# hour                                      0
# ride_date                                 0
# Event                                     0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Ride Distance                         51280
# Booking Value                         51280
# Avg VTAT                              11207
# Avg CTAT                              51280
# Cancelled Rides by Customer          149355
# Reason for cancelling by Customer    149355
# Cancelled Rides by Driver            131790
# Driver Cancellation Reason           131790
# Incomplete Rides                     150946
# Incomplete Rides Reason              150946
# Driver Ratings                        60943
# Customer Rating                       60943
# Payment Method                        51280
# dtype: int64

# %%
print("Duplicated Rows:",df.duplicated().sum())
# Out:
# Duplicated Rows: 1006
